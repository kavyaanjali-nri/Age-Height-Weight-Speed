# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyaanjali-nri/Age-Height-Weight-Speed/blob/main/Copy_of_Untitled12_ipynd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ds=pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications.csv')

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]

# %%
ds.shape
# Out:
# (690, 16)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
pd.set_option('display.max_rows',10)

# %%
pd.set_option('display.max_columns',10)

# %%
ds.head(10)
# Out:
#    CustomerID  A1     A2      A3  A4  ...  A11  A12  A13   A14  Class
# 0    15776156   1  22.08  11.460   2  ...    1    2  100  1213      0
# 1    15739548   0  22.67   7.000   2  ...    0    2  160     1      0
# 2    15662854   0  29.58   1.750   1  ...    1    2  280     1      0
# 3    15687688   0  21.67  11.500   1  ...    1    2    0     1      1
# 4    15715750   1  20.17   8.170   2  ...    0    2   60   159      1
# 5    15571121   0  15.83   0.585   2  ...    0    2  100     1      1
# 6    15726466   1  17.42   6.500   2  ...    0    2   60   101      0
# 7    15660390   0  58.67   4.460   2  ...    0    2   43   561      1
# 8    15663942   1  27.83   1.000   1  ...    0    2  176   538      0
# 9    15638610   0  55.75   7.080   2  ...    1    2  100    51      0
#
# [10 rows x 16 columns]

# %%
ds.tail(10)
# Out:
#      CustomerID  A1     A2      A3  A4  ...  A11  A12  A13   A14  Class
# 680    15790689   1  21.17   0.000   2  ...    1    1    0     1      0
# 681    15665181   1  35.25  16.500   1  ...    0    2   80     1      0
# 682    15633608   0  22.92  11.585   2  ...    0    2   80  1350      1
# 683    15805261   0  48.17   1.335   2  ...    0    2    0   121      0
# 684    15740356   1  43.00   0.290   1  ...    0    2  100   376      1
# 685    15808223   1  31.57  10.500   2  ...    0    2    0     1      1
# 686    15769980   1  20.67   0.415   2  ...    0    2    0    45      0
# 687    15675450   0  18.83   9.540   2  ...    0    2  100     1      1
# 688    15776494   0  27.42  14.500   2  ...    0    2  120    12      1
# 689    15592412   1  41.00   0.040   2  ...    0    1  560     1      1
#
# [10 rows x 16 columns]

# %%
import pandas as pd
import random
age = []
height = []
weight= []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
idata = {'age':age,'height':height,'weight':weight,'speed':speed}

idata
# Out:
# {'age': [66,
#   61,
#   92,
#   74,
#   18,
#   91,
#   11,
#   20,
#   29,
#   9,
#   68,
#   59,
#   6,
#   92,
#   8,
#   29,
#   20,
#   82,
#   7,
#   68,
#   45,
#   100,
#   86,
#   69,
#   88,
#   29,
#   90,
#   57,
#   2,
#   63,
#   53,
#   76,
#   9,
#   97,
#   58,
#   54,
#   49,
#   58,
#   72,
#   90,
#   21,
#   81,
#   14,
#   14,
#   62,
#   18,
#   98,
#   69,
#   25,
#   50,
#   10,
#   29,
#   73,
#   90,
#   86,
#   0,
#   1,
#   24,
#   72,
#   2,
#   51,
#   40,
#   72,
#   95,
#   6,
#   0,
#   29,
#   54,
#   74,
#   0,
#   64,
#   44,
#   39,
#   64,
#   46,
#   57,
#   65,
#   22,
#   1,
#   96,
#   66,
#   45,
#   38,
#   95,
#   68,
#   74,
#   26,
#   46,
#   27,
#   89,
#   97,
#   70,
#   62,
#   64,
#   20,
#   90,
#   20,
#   58,
#   25,
#   43],
#  'height': [70,
#   91,
#   99,
#   64,
#   61,
#   53,
#   30,
#   75,
#   38,
#   90,
#   39,
#   27,
#   50,
#   44,
#   63,
#   95,
#   13,
#   13,
#   33,
#   87,
#   100,
#   28,
#   57,
#   39,
#   55,
#   16,
#   33,
#   8,
#   98,
#   67,
#   85,
#   57,
#   61,
#   93,
#   93,
#   93,
#   56,
#   16,
#   87,
#   59,
#   90,
#   35,
#   68,
#   56,
#   24,
#   70,
#   3,
#   55,
#   22,
#   29,
#   12,
#   85,
#   94,
#   58,
#   80,
#   44,
#   10,
#   15,
#   28,
#   64,
#   68,
#   100,
#   18,
#   41,
#   92,
#   11,
#   33,
#   74,
#   44,
#   45,
#   71,
#   92,
#   54,
#   74,
#   65,
#   44,
#   65,
#   62,
#   71,
#   93,
#   41,
#   42,
#   32,
#   25,
#   83,
#   25,
#   66,
#   89,
#   83,
#   96,
#   84,
#   75,
#   54,
#   14,
#   42,
#   16,
#   90,
#   73,
#   83,
#   62],
#  'weight': [42,
#   74,
#   68,
#   22,
#   100,
#   92,
#   36,
#   73,
#   33,
#   35,
#   20,
#   89,
#   6,
#   87,
#   48,
#   95,
#   76,
#   6,
#   53,
#   37,
#   43,
#   42,
#   15,
#   14,
#   86,
#   62,
#   84,
#   43,
#   95,
#   94,
#   13,
#   89,
#   67,
#   43,
#   62,
#   19,
#   35,
#   66,
#   98,
#   27,
#   31,
#   12,
#   76,
#   91,
#   60,
#   16,
#   67,
#   51,
#   19,
#   91,
#   82,
#   21,
#   28,
#   5,
#   28,
#   52,
#   22,
#   4,
#   20,
#   42,
#   59,
#   92,
#   48,
#   100,
#   92,
#   40,
#   95,
#   48,
#   83,
#   72,
#   4,
#   91,
#   1,
#   26,
#   27,
#   11,
#   22,
#   92,
#   58,
#   41,
#   23,
#   90,
#   24,
#   4,
#   29,
#   33,
#   57,
#   98,
#   93,
#   81,
#   55,
#   75,
#   47,
#   99,
#   17,
#   35,
#   28,
#   47,
#   7,
#   87],
#  'speed': [88,
#   60,
#   47,
#   86,
#   49,
#   61,
#   47,
#   67,
#   6,
#   72,
#   40,
#   61,
#   74,
#   6,
#   92,
#   56,
#   64,
#   41,
#   34,
#   76,
#   29,
#   19,
#   100,
#   74,
#   40,
#   37,
#   75,
#   38,
#   71,
#   9,
#   12,
#   15,
#   67,
#   3,
#   52,
#   68,
#   36,
#   19,
#   71,
#   41,
#   99,
#   87,
#   43,
#   17,
#   88,
#   93,
#   43,
#   47,
#   26,
#   96,
#   30,
#   52,
#   28,
#   38,
#   22,
#   91,
#   87,
#   93,
#   64,
#   57,
#   94,
#   0,
#   21,
#   66,
#   10,
#   21,
#   33,
#   78,
#   69,
#   30,
#   70,
#   28,
#   96,
#   1,
#   74,
#   59,
#   53,
#   35,
#   0,
#   72,
#   23,
#   79,
#   53,
#   5,
#   5,
#   27,
#   46,
#   3,
#   60,
#   51,
#   37,
#   89,
#   91,
#   24,
#   86,
#   3,
#   59,
#   5,
#   69,
#   27]}

# %%
df1 = pd.DataFrame(idata)
df1. describe()
# Out:
#               age      height      weight       speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    50.360000   56.700000   51.380000   49.560000
# std     30.123155   27.354943   30.484233   28.823854
# min      0.000000    3.000000    1.000000    0.000000
# 25%     23.500000   33.000000   25.500000   27.000000
# 50%     55.500000   58.500000   47.500000   50.000000
# 75%     72.250000   83.000000   82.250000   72.000000
# max    100.000000  100.000000  100.000000  100.000000

# %%
df1[['age','height']]
# Out:
#     age  height
# 0    66      70
# 1    61      91
# 2    92      99
# 3    74      64
# 4    18      61
# ..  ...     ...
# 95   90      16
# 96   20      90
# 97   58      73
# 98   25      83
# 99   43      62
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['age','height']]
# Out:
#    age  height
# 0   66      70
# 3   74      64

# %%
df1.sort_index()
# Out:
#     age  height  weight  speed
# 0    66      70      42     88
# 1    61      91      74     60
# 2    92      99      68     47
# 3    74      64      22     86
# 4    18      61     100     49
# ..  ...     ...     ...    ...
# 95   90      16      35      3
# 96   20      90      28     59
# 97   58      73      47      5
# 98   25      83       7     69
# 99   43      62      87     27
#
# [100 rows x 4 columns]
