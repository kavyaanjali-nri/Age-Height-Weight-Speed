# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyaanjali-nri/Age-Height-Weight-Speed/blob/main/Creating%20to%20Analyze%20datas%20Using%20Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
from google.colab import drive

# %%
# mount the drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read file form the drive
import pandas as pd

# %%
datasetpath= '/content/drive/MyDrive/matches_1930_2022.csv'

# %%
df = pd.read_csv(datasetpath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['home_team', 'away_team', 'home_score', 'home_xg', 'home_penalty',
#        'away_score', 'away_xg', 'away_penalty', 'home_manager', 'home_captain',
#        'away_manager', 'away_captain', 'Attendance', 'Venue', 'Officials',
#        'Round', 'Date', 'Score', 'Referee', 'Notes', 'Host', 'Year',
#        'home_goal', 'away_goal', 'home_goal_long', 'away_goal_long',
#        'home_own_goal', 'away_own_goal', 'home_penalty_goal',
#        'away_penalty_goal', 'home_penalty_miss_long', 'away_penalty_miss_long',
#        'home_penalty_shootout_goal_long', 'away_penalty_shootout_goal_long',
#        'home_penalty_shootout_miss_long', 'away_penalty_shootout_miss_long',
#        'home_red_card', 'away_red_card', 'home_yellow_red_card',
#        'away_yellow_red_card', 'home_yellow_card_long',
#        'away_yellow_card_long', 'home_substitute_in_long',
#        'away_substitute_in_long'],
#       dtype='object')

# %%
df['home_team'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 964 entries, 0 to 963
# Series name: home_team
# Non-Null Count  Dtype
# --------------  -----
# 964 non-null    object
# dtypes: object(1)
# memory usage: 7.7+ KB

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# Date
# 1958-06-15    8
# 1958-06-08    8
# 1934-05-27    8
# 1958-06-11    7
# 1938-06-05    6
#              ..
# 2006-07-08    1
# 2006-07-05    1
# 2006-07-04    1
# 1966-07-25    1
# 2022-12-18    1
# Name: count, Length: 378, dtype: int64

# %%
df['Score'].value_counts()
# Out:
# Score
# 1–0            118
# 2–1            107
# 1–1             75
# 2–0             71
# 0–0             66
#               ...
# (4) 2–2 (3)      1
# (3) 0–0 (2)      1
# (4) 2–2 (5)      1
# (4) 1–1 (3)      1
# 6–5              1
# Name: count, Length: 71, dtype: int64

# %%
ScoredAboveZero=df['Score']>'0-0'

# %%
df[ScoredAboveZero]
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# 5          England    France           1      2.4           NaN           2
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# 5        0.9           NaN  Gareth Southgate            Harry Kane  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# 5                               NaN                             NaN
# ..                              ...                             ...
# 959                             NaN                             NaN
# 960                             NaN                             NaN
# 961                             NaN                             NaN
# 962                             NaN                             NaN
# 963                             NaN                             NaN
#
#      home_red_card         away_red_card   home_yellow_red_card  \
# 1              NaN                   NaN                    NaN
# 2              NaN                   NaN                    NaN
# 3              NaN                   NaN                    NaN
# 4              NaN                   NaN  Walid Cheddira · 90+3
# 5              NaN                   NaN                    NaN
# ..             ...                   ...                    ...
# 959            NaN                   NaN                    NaN
# 960            NaN                   NaN                    NaN
# 961            NaN  Plácido Galindo · 70                    NaN
# 962            NaN                   NaN                    NaN
# 963            NaN                   NaN                    NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4                    NaN  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# 5                    NaN                   ['90&rsquor;|1:2|Harry Maguire']
# ..                   ...                                                ...
# 959                  NaN                                                NaN
# 960                  NaN                                                NaN
# 961                  NaN                                                NaN
# 962                  NaN                                                NaN
# 963                  NaN                                                NaN
#
#                                  away_yellow_card_long  \
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# 5    ['43&rsquor;|0:1|Antoine Griezmann', '47&rsquo...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# 5    ['79&rsquor;|1:2|Raheem Sterling|for Bukayo Sa...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# 5    ['79&rsquor;|1:2|Kingsley Coman|for Ousmane De...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [929 rows x 44 columns]

# %%
 ScoredByBrazil = df['home_team'] == 'Brazil'

# %%
 df[ScoredAboveZero & ScoredByBrazil]
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 11     Brazil  Korea Republic           4      3.6           NaN           1
# 34     Brazil     Switzerland           1      1.0           NaN           0
# 51     Brazil          Serbia           2      2.4           NaN           0
# 71     Brazil         Belgium           1      2.8           NaN           2
# 74     Brazil          Mexico           2      2.7           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 911    Brazil          Sweden           4      NaN           NaN           2
# 915    Brazil  Czechoslovakia           2      NaN           NaN           1
# 917    Brazil  Czechoslovakia           1      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 951    Brazil         Bolivia           4      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager               home_captain  \
# 11       0.5           NaN                 Tite               Thiago Silva
# 34       0.3           NaN                 Tite               Thiago Silva
# 51       0.2           NaN                 Tite               Thiago Silva
# 71       0.5           NaN                 Tite                    Miranda
# 74       0.7           NaN                 Tite               Thiago Silva
# ..       ...           ...                  ...                        ...
# 911      NaN           NaN       Ademar Pimenta                   Leônidas
# 915      NaN           NaN       Ademar Pimenta                   Leônidas
# 917      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 926      NaN           NaN       Ademar Pimenta  Martim Mércio da Silveira
# 951      NaN           NaN  Pindaro De Carvalho                  Preguinho
#
#      ... home_penalty_shootout_miss_long away_penalty_shootout_miss_long  \
# 11   ...                             NaN                             NaN
# 34   ...                             NaN                             NaN
# 51   ...                             NaN                             NaN
# 71   ...                             NaN                             NaN
# 74   ...                             NaN                             NaN
# ..   ...                             ...                             ...
# 911  ...                             NaN                             NaN
# 915  ...                             NaN                             NaN
# 917  ...                             NaN                             NaN
# 926  ...                             NaN                             NaN
# 951  ...                             NaN                             NaN
#
#                               home_red_card  away_red_card  \
# 11                                      NaN            NaN
# 34                                      NaN            NaN
# 51                                      NaN            NaN
# 71                                      NaN            NaN
# 74                                      NaN            NaN
# ..                                      ...            ...
# 911                                     NaN            NaN
# 915                                     NaN            NaN
# 917  Zezé Procópio · 14|Arthur Machado · 89  Jan Říha · 89
# 926                                     NaN            NaN
# 951                                     NaN            NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 11                   NaN                  NaN
# 34                   NaN                  NaN
# 51                   NaN                  NaN
# 71                   NaN                  NaN
# 74                   NaN                  NaN
# ..                   ...                  ...
# 911                  NaN                  NaN
# 915                  NaN                  NaN
# 917                  NaN                  NaN
# 926                  NaN                  NaN
# 951                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 11                                                 NaN
# 34                             ['52&rsquor;|0:0|Fred']
# 51                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                  away_yellow_card_long  \
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 34                    ['50&rsquor;|0:0|Fabian Rieder']
# 51   ['7&rsquor;|0:0|Strahinja Pavlović', '49&rsquo...
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                home_substitute_in_long  \
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 34   ['46&rsquor;|0:0|Rodrygo|for Lucas Paquetá', '...
# 51   ['75&rsquor;|2:0|Fred|for Lucas Paquetá', '76&...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
#                                away_substitute_in_long
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 34   ['59&rsquor;|0:0|Edimilson Fernandes|for Ruben...
# 51   ['57&rsquor;|0:0|Ivan Ilić|for Nemanja Gudelj'...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# ..                                                 ...
# 911                                                NaN
# 915                                                NaN
# 917                                                NaN
# 926                                                NaN
# 951                                                NaN
#
# [81 rows x 44 columns]

# %%
brazildf = df[ScoredAboveZero & ScoredByBrazil].sort_values(by = 'home_score',ascending= True)

# %%
brazildf
# Out:
#     home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 512    Brazil       Argentina           0      NaN           NaN           1
# 261    Brazil          France           0      NaN           NaN           1
# 695    Brazil          Poland           0      NaN           NaN           1
# 817    Brazil  Czechoslovakia           0      NaN           NaN           0
# 679    Brazil           Spain           0      NaN           NaN           0
# ..        ...             ...         ...      ...           ...         ...
# 887    Brazil          Mexico           5      NaN           NaN           0
# 831    Brazil          France           5      NaN           NaN           2
# 891    Brazil           Spain           6      NaN           NaN           1
# 926    Brazil          Poland           6      NaN           NaN           5
# 893    Brazil          Sweden           7      NaN           NaN           1
#
#      away_xg  away_penalty             home_manager  \
# 512      NaN           NaN       Sebastiao Lazaroni
# 261      NaN           NaN  Carlos Alberto Parreira
# 695      NaN           NaN            Mario Zagallo
# 817      NaN           NaN           Aymore Moreira
# 679      NaN           NaN         Claudio Coutinho
# ..       ...           ...                      ...
# 887      NaN           NaN             Zeze Moreira
# 831      NaN           NaN            Vicente Feola
# 891      NaN           NaN             Flavio Costa
# 926      NaN           NaN           Ademar Pimenta
# 893      NaN           NaN             Flavio Costa
#
#                   home_captain  ... home_penalty_shootout_miss_long  \
# 512              Ricardo Gomes  ...                             NaN
# 261                        NaN  ...                             NaN
# 695              Marinho Peres  ...                             NaN
# 817                Mauro Ramos  ...                             NaN
# 679               Émerson Leão  ...                             NaN
# ..                         ...  ...                             ...
# 887                      Bauer  ...                             NaN
# 831         Hilderaldo Bellini  ...                             NaN
# 891           Augusto da Costa  ...                             NaN
# 926  Martim Mércio da Silveira  ...                             NaN
# 893           Augusto da Costa  ...                             NaN
#
#     away_penalty_shootout_miss_long       home_red_card away_red_card  \
# 512                             NaN  Ricardo Gomes · 85           NaN
# 261                             NaN                 NaN           NaN
# 695                             NaN                 NaN           NaN
# 817                             NaN                 NaN           NaN
# 679                             NaN                 NaN           NaN
# ..                              ...                 ...           ...
# 887                             NaN                 NaN           NaN
# 831                             NaN                 NaN           NaN
# 891                             NaN                 NaN           NaN
# 926                             NaN                 NaN           NaN
# 893                             NaN                 NaN           NaN
#
#     home_yellow_red_card away_yellow_red_card  \
# 512                  NaN                  NaN
# 261                  NaN                  NaN
# 695                  NaN                  NaN
# 817                  NaN                  NaN
# 679                  NaN                  NaN
# ..                   ...                  ...
# 887                  NaN                  NaN
# 831                  NaN                  NaN
# 891                  NaN                  NaN
# 926                  NaN                  NaN
# 893                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 512  ['40&rsquor;|0:0|Ricardo Rocha', '50&rsquor;|0...
# 261  ['25&rsquor;|0:0|Cafú', '45&rsquor;|0:0|Juan',...
# 695                       ['76&rsquor;|0:1|Jairzinho']
# 817                                                NaN
# 679                                                NaN
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                           ['1&rsquor;|0:0|Bigode']
# 926                                                NaN
# 893                                                NaN
#
#                                  away_yellow_card_long  \
# 512  ['27&rsquor;|0:0|Pedro Monzón', '28&rsquor;|0:...
# 261  ['74&rsquor;|0:1|Willy Sagnol', '87&rsquor;|0:...
# 695               ['71&rsquor;|0:0|Henryk Kasperczak']
# 817                                                NaN
# 679                     ['1&rsquor;|0:0|Eugenio Leal']
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                home_substitute_in_long  \
# 512  ['83&rsquor;|0:1|Silas Pereira', '83&rsquor;|0...
# 261  ['63&rsquor;|0:1|Adriano|for Juninho Pernambuc...
# 695   ['66&rsquor;|0:0|Mirandinha|for Ademir da Guia']
# 817                                                NaN
# 679  ['70&rsquor;|0:0|Gilberto Alves|for Nelinho', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
#                                away_substitute_in_long
# 512  ['61&rsquor;|0:0|Gabriel Calderón|for Pedro Tr...
# 261  ['77&rsquor;|0:1|Sidney Govou|for Franck Ribér...
# 695  ['73&rsquor;|0:0|Lesław Ćmikiewicz|for Henryk ...
# 817                                                NaN
# 679  ['51&rsquor;|0:0|Antonio Biosca|for Migueli', ...
# ..                                                 ...
# 887                                                NaN
# 831                                                NaN
# 891                                                NaN
# 926                                                NaN
# 893                                                NaN
#
# [81 rows x 44 columns]

# %%
brazildf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 512 to 893
# Data columns (total 44 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   home_team                        81 non-null     object
#  1   away_team                        81 non-null     object
#  2   home_score                       81 non-null     int64
#  3   home_xg                          7 non-null      float64
#  4   home_penalty                     0 non-null      float64
#  5   away_score                       81 non-null     int64
#  6   away_xg                          7 non-null      float64
#  7   away_penalty                     0 non-null      float64
#  8   home_manager                     81 non-null     object
#  9   home_captain                     59 non-null     object
#  10  away_manager                     81 non-null     object
#  11  away_captain                     59 non-null     object
#  12  Attendance                       81 non-null     int64
#  13  Venue                            81 non-null     object
#  14  Officials                        64 non-null     object
#  15  Round                            81 non-null     object
#  16  Date                             81 non-null     object
#  17  Score                            81 non-null     object
#  18  Referee                          64 non-null     object
#  19  Notes                            3 non-null      object
#  20  Host                             81 non-null     object
#  21  Year                             81 non-null     int64
#  22  home_goal                        71 non-null     object
#  23  away_goal                        38 non-null     object
#  24  home_goal_long                   71 non-null     object
#  25  away_goal_long                   38 non-null     object
#  26  home_own_goal                    2 non-null      object
#  27  away_own_goal                    2 non-null      object
#  28  home_penalty_goal                8 non-null      object
#  29  away_penalty_goal                8 non-null      object
#  30  home_penalty_miss_long           0 non-null      object
#  31  away_penalty_miss_long           0 non-null      object
#  32  home_penalty_shootout_goal_long  0 non-null      object
#  33  away_penalty_shootout_goal_long  0 non-null      object
#  34  home_penalty_shootout_miss_long  0 non-null      object
#  35  away_penalty_shootout_miss_long  0 non-null      object
#  36  home_red_card                    4 non-null      object
#  37  away_red_card                    3 non-null      object
#  38  home_yellow_red_card             1 non-null      object
#  39  away_yellow_red_card             3 non-null      object
#  40  home_yellow_card_long            43 non-null     object
#  41  away_yellow_card_long            47 non-null     object
#  42  home_substitute_in_long          51 non-null     object
#  43  away_substitute_in_long          55 non-null     object
# dtypes: float64(4), int64(4), object(36)
# memory usage: 28.5+ KB

# %%
 # %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
 brazildf.plot(x='home_score',y='away_score',kind='scatter')
 plt.xlabel('Home Score')
 plt.ylabel('Away Score')
 plt.legend('Takeaway')
 plt.title('Brazil Matches')
 plt.show()

# %%
 brazildf.plot(x='Year',y='home_score',kind='hexbin')
 plt.xlabel('Year')
 plt.ylabel('Home Score')
 plt.legend('Takeaway')
 plt.title('Brazil Matches')
 plt.show()

# %%
def AnalyzeFrance():
  matchesPlayed=df['home_team'].value_counts()['France']
  print(f'Totle Number of matchesPlayed by france is:{matchesPlayed}')

# %%
AnalyzeFrance()
# Out:
# Totle Number of matchesPlayed by france is:38

# %%
def AnalyzeTowns():
  TownData=df['home_team'].value_counts()
  for _ in TownData.index:
    print(f'Totle Number of matches played by {_} is :{TownData[_]}')

# %%
AnalyzeTowns()
# Out:
# Totle Number of matches played by Brazil is :85
# Totle Number of matches played by Argentina is :59
# Totle Number of matches played by Italy is :57
# Totle Number of matches played by England is :40
# Totle Number of matches played by Germany is :40
# Totle Number of matches played by France is :38
# Totle Number of matches played by West Germany is :38
# Totle Number of matches played by Spain is :34
# Totle Number of matches played by Netherlands is :33
# Totle Number of matches played by Uruguay is :33
# Totle Number of matches played by Sweden is :30
# Totle Number of matches played by Belgium is :23
# Totle Number of matches played by Portugal is :21
# Totle Number of matches played by Poland is :20
# Totle Number of matches played by Soviet Union is :18
# Totle Number of matches played by Hungary is :18
# Totle Number of matches played by Mexico is :18
# Totle Number of matches played by Korea Republic is :18
# Totle Number of matches played by Switzerland is :16
# Totle Number of matches played by United States is :16
# Totle Number of matches played by Yugoslavia is :16
# Totle Number of matches played by Japan is :15
# Totle Number of matches played by Chile is :14
# Totle Number of matches played by Cameroon is :13
# Totle Number of matches played by Austria is :12
# Totle Number of matches played by Paraguay is :11
# Totle Number of matches played by Nigeria is :11
# Totle Number of matches played by Denmark is :10
# Totle Number of matches played by Czechoslovakia is :10
# Totle Number of matches played by Croatia is :10
# Totle Number of matches played by Scotland is :9
# Totle Number of matches played by Romania is :9
# Totle Number of matches played by Colombia is :8
# Totle Number of matches played by Morocco is :8
# Totle Number of matches played by Saudi Arabia is :8
# Totle Number of matches played by Australia is :8
# Totle Number of matches played by Costa Rica is :8
# Totle Number of matches played by Tunisia is :7
# Totle Number of matches played by Bulgaria is :7
# Totle Number of matches played by Peru is :6
# Totle Number of matches played by South Africa is :6
# Totle Number of matches played by Russia is :6
# Totle Number of matches played by Algeria is :6
# Totle Number of matches played by Ecuador is :5
# Totle Number of matches played by IR Iran is :5
# Totle Number of matches played by Ghana is :5
# Totle Number of matches played by Republic of Ireland is :5
# Totle Number of matches played by Honduras is :5
# Totle Number of matches played by Northern Ireland is :5
# Totle Number of matches played by Serbia is :4
# Totle Number of matches played by Greece is :4
# Totle Number of matches played by Senegal is :4
# Totle Number of matches played by Korea DPR is :3
# Totle Number of matches played by Germany DR is :3
# Totle Number of matches played by Slovenia is :3
# Totle Number of matches played by Côte d'Ivoire is :3
# Totle Number of matches played by Wales is :3
# Totle Number of matches played by Iraq is :2
# Totle Number of matches played by Zaire is :2
# Totle Number of matches played by Cuba is :2
# Totle Number of matches played by Canada is :2
# Totle Number of matches played by Qatar is :2
# Totle Number of matches played by Slovakia is :2
# Totle Number of matches played by Czech Republic is :2
# Totle Number of matches played by Togo is :2
# Totle Number of matches played by Türkiye is :2
# Totle Number of matches played by China PR is :1
# Totle Number of matches played by United Arab Emirates is :1
# Totle Number of matches played by Haiti is :1
# Totle Number of matches played by Panama is :1
# Totle Number of matches played by Iceland is :1
# Totle Number of matches played by Egypt is :1
# Totle Number of matches played by Ukraine is :1
# Totle Number of matches played by New Zealand is :1
# Totle Number of matches played by Norway is :1
# Totle Number of matches played by Bolivia is :1
# Totle Number of matches played by Serbia and Montenegro is :1
# Totle Number of matches played by Jamaica is :1
# Totle Number of matches played by FR Yugoslavia is :1
# Totle Number of matches played by Angola is :1
# Totle Number of matches played by Trinidad and Tobago is :1
# Totle Number of matches played by Bosnia and Herzegovina is :1

# %%
# %matplotlib inline

# %%
Town30= df['home_team'].value_counts().values>30

# %%
Town30
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
from matplotlib import pyplot as plt

# %%
def MatchesPlayedByTown():
   townName=[]
   matchesPlayed=[]
   TownData=df['home_team'].value_counts()
   for _ in TownData.index:
      if TownData[_]>30:
        townName.append(_)
        matchesPlayed.append(TownData[_])
   plt.bar(matchesPlayed,townName)
   plt.ylabel('Town Name')
   plt.xlabel('matchesplayed')
   plt.title('matches played by Towns')
   plt.show()

# %%
MatchesPlayedByTown()

# %%
def MatchesPlayedByTown2():
  Above30=df['home_team'].value_counts()
  filteredData=Above30[Above30>30]
  filteredData.plot(kind='barh')

# %%
MatchesPlayedByTown2()

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df['home_team'].value_counts()
# Out:
# home_team
# Brazil                    85
# Argentina                 59
# Italy                     57
# England                   40
# Germany                   40
#                           ..
# Jamaica                    1
# FR Yugoslavia              1
# Angola                     1
# Trinidad and Tobago        1
# Bosnia and Herzegovina     1
# Name: count, Length: 82, dtype: int64

# %%
filteredData= df ['home_team'].value_counts()

# %%
 f2=filteredData[filteredData>=40].index

# %%
f2
# Out:
# Index(['Brazil', 'Argentina', 'Italy', 'England', 'Germany'], dtype='object', name='home_team')

# %%
 df2 = df[df["home_team"].isin(f2)]

# %%
df2
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 3    Argentina         Croatia           3      2.3           NaN           0
# 5      England          France           1      2.4           NaN           2
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 13     England         Senegal           3      1.0           NaN           0
# ..         ...             ...         ...      ...           ...         ...
# 948  Argentina   United States           6      NaN           NaN           1
# 949  Argentina           Chile           3      NaN           NaN           1
# 951     Brazil         Bolivia           4      NaN           NaN           0
# 954  Argentina          Mexico           6      NaN           NaN           3
# 959  Argentina          France           1      NaN           NaN           0
#
#      away_xg  away_penalty         home_manager     home_captain  ...  \
# 0        2.2           2.0       Lionel Scaloni     Lionel Messi  ...
# 3        0.5           NaN       Lionel Scaloni     Lionel Messi  ...
# 5        0.9           NaN     Gareth Southgate       Harry Kane  ...
# 11       0.5           NaN                 Tite     Thiago Silva  ...
# 13       0.8           NaN     Gareth Southgate       Harry Kane  ...
# ..       ...           ...                  ...              ...  ...
# 948      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 949      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
# 951      NaN           NaN  Pindaro De Carvalho        Preguinho  ...
# 954      NaN           NaN     Francisco Olazar     Ángel Bossio  ...
# 959      NaN           NaN     Francisco Olazar  Manuel Ferreira  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 3                               NaN
# 5                               NaN
# 11                              NaN
# 13                              NaN
# ..                              ...
# 948                             NaN
# 949                             NaN
# 951                             NaN
# 954                             NaN
# 959                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 3                                                  NaN            NaN
# 5                                                  NaN            NaN
# 11                                                 NaN            NaN
# 13                                                 NaN            NaN
# ..                                                 ...            ...
# 948                                                NaN            NaN
# 949                                                NaN            NaN
# 951                                                NaN            NaN
# 954                                                NaN            NaN
# 959                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 3             NaN                  NaN                  NaN
# 5             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 13            NaN                  NaN                  NaN
# ..            ...                  ...                  ...
# 948           NaN                  NaN                  NaN
# 949           NaN                  NaN                  NaN
# 951           NaN                  NaN                  NaN
# 954           NaN                  NaN                  NaN
# 959           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 5                     ['90&rsquor;|1:2|Harry Maguire']
# 11                                                 NaN
# 13                                                 NaN
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 5    ['43&rsquor;|0:1|Antoine Griezmann', '47&rsquo...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 13                ['76&rsquor;|3:0|Kalidou Koulibaly']
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 5    ['79&rsquor;|1:2|Raheem Sterling|for Bukayo Sa...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 13   ['65&rsquor;|3:0|Jack Grealish|for Phil Foden'...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 5    ['79&rsquor;|1:2|Kingsley Coman|for Ousmane De...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 13   ['46&rsquor;|2:0|Pape Matar Sarr|for Krépin Di...
# ..                                                 ...
# 948                                                NaN
# 949                                                NaN
# 951                                                NaN
# 954                                                NaN
# 959                                                NaN
#
# [281 rows x 44 columns]

# %%
 df2["home_xg"].value_counts()
# Out:
# home_xg
# 2.2    2
# 2.4    2
# 1.0    2
# 1.4    2
# 2.8    2
# 2.1    1
# 1.3    1
# 2.6    1
# 0.9    1
# 2.7    1
# 3.3    1
# 2.3    1
# 3.1    1
# 0.8    1
# 0.3    1
# 1.6    1
# 3.6    1
# 1.9    1
# Name: count, dtype: int64

# %%
# %matplotlib inline

# %%
 df2.plot(x = 'home_team',y = 'home_xg',kind = 'bar')
# Out:
# <Axes: xlabel='home_team'>

# %%
 f3 = df2["home_xg"] > 2.5

# %%
 df3 = df2[f3]

# %%
 df3
# Out:
#      home_team       away_team  home_score  home_xg  home_penalty  away_score  \
# 0    Argentina          France           3      3.3           4.0           3
# 11      Brazil  Korea Republic           4      3.6           NaN           1
# 53     Germany           Japan           1      3.1           NaN           2
# 71      Brazil         Belgium           1      2.8           NaN           2
# 74      Brazil          Mexico           2      2.7           NaN           0
# 96     England          Panama           6      2.8           NaN           1
# 102     Brazil      Costa Rica           2      2.6           NaN           0
#
#      away_xg  away_penalty      home_manager  home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni  Lionel Messi  ...
# 11       0.5           NaN              Tite  Thiago Silva  ...
# 53       1.5           NaN       Hansi Flick  Manuel Neuer  ...
# 71       0.5           NaN              Tite       Miranda  ...
# 74       0.7           NaN              Tite  Thiago Silva  ...
# 96       1.1           NaN  Gareth Southgate    Harry Kane  ...
# 102      0.1           NaN              Tite  Thiago Silva  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 11                              NaN
# 53                              NaN
# 71                              NaN
# 74                              NaN
# 96                              NaN
# 102                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 11                                                 NaN            NaN
# 53                                                 NaN            NaN
# 71                                                 NaN            NaN
# 74                                                 NaN            NaN
# 96                                                 NaN            NaN
# 102                                                NaN            NaN
#
#     away_red_card home_yellow_red_card away_yellow_red_card  \
# 0             NaN                  NaN                  NaN
# 11            NaN                  NaN                  NaN
# 53            NaN                  NaN                  NaN
# 71            NaN                  NaN                  NaN
# 74            NaN                  NaN                  NaN
# 96            NaN                  NaN                  NaN
# 102           NaN                  NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 11                                                 NaN
# 53                                                 NaN
# 71   ['85&rsquor;|1:2|Fernandinho', '90&rsquor;|1:2...
# 74   ['43&rsquor;|0:0|Filipe Luís', '59&rsquor;|1:0...
# 96               ['23&rsquor;|2:0|Ruben Loftus-Cheek']
# 102  ['81&rsquor;|0:0|Philippe Coutinho', '81&rsquo...
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 11                   ['44&rsquor;|4:0|Jung Woo-young']
# 53                                                 NaN
# 71   ['47&rsquor;|0:2|Toby Alderweireld', '71&rsquo...
# 74   ['38&rsquor;|0:0|Edson Álvarez', '55&rsquor;|1...
# 96   ['10&rsquor;|1:0|Armando Cooper', '44&rsquor;|...
# 102                   ['84&rsquor;|0:0|Johnny Acosta']
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 11   ['63&rsquor;|4:0|Dani Alves|for Éder Militão',...
# 53   ['67&rsquor;|1:0|Jonas Hofmann|for Thomas Müll...
# 71   ['46&rsquor;|0:2|Roberto Firmino|for Willian',...
# 74   ['80&rsquor;|1:0|Fernandinho|for Paulinho', '8...
# 96   ['63&rsquor;|6:0|Jamie Vardy|for Harry Kane', ...
# 102  ['46&rsquor;|0:0|Douglas Costa|for Willian', '...
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 11   ['46&rsquor;|4:0|Hong Chul|for Kim Jin-su', '4...
# 53   ['46&rsquor;|1:0|Takehiro Tomiyasu|for Takefus...
# 71   ['83&rsquor;|1:2|Thomas Vermaelen|for Nacer Ch...
# 74   ['46&rsquor;|0:0|Miguel Layún|for Rafael Márqu...
# 96   ['62&rsquor;|5:0|Ricardo Ávila|for Aníbal Godo...
# 102  ['54&rsquor;|0:0|Christian Bolaños|for Marco U...
#
# [7 rows x 44 columns]

# %%
 from matplotlib import pyplot as plt

# %%
df3.plot(x="home_team",y="home_xg",kind="bar")
# Out:
# <Axes: xlabel='home_team'>

# %%
 df3.plot(x="home_team",y= ['home_score','home_xg'],kind="bar",color=["green","red"])
# Out:
# <Axes: xlabel='home_team'>

# %%
# groupb

# %%
 df.groupby("home_team")

# %%
df.describe()
# Out:
#        home_score     home_xg  home_penalty  away_score     away_xg  \
# count  964.000000  128.000000     35.000000  964.000000  128.000000
# mean     1.776971    1.435938      3.285714    1.044606    1.192187
# std      1.596676    0.860391      1.226459    1.071233    0.809258
# min      0.000000    0.100000      0.000000    0.000000    0.000000
# 25%      1.000000    0.800000      3.000000    0.000000    0.600000
# 50%      1.000000    1.300000      3.000000    1.000000    1.000000
# 75%      3.000000    1.925000      4.000000    2.000000    1.525000
# max     10.000000    5.200000      5.000000    7.000000    5.700000
#
#        away_penalty     Attendance         Year
# count     35.000000     964.000000   964.000000
# mean       3.057143   45693.374481  1989.244813
# std        1.136115   22704.131689    24.014409
# min        0.000000    2000.000000  1930.000000
# 25%        2.000000   31800.000000  1974.000000
# 50%        3.000000   42725.000000  1994.000000
# 75%        4.000000   60984.500000  2010.000000
# max        5.000000  173850.000000  2022.000000

# %%
 dg = df.groupby("home_team")["home_xg"]
 print(dg.mean())
# Out:
# home_team
# Algeria              NaN
# Angola               NaN
# Argentina       1.842857
# Australia       0.750000
# Austria              NaN
#                   ...
# Uruguay         1.240000
# Wales           0.600000
# West Germany         NaN
# Yugoslavia           NaN
# Zaire                NaN
# Name: home_xg, Length: 82, dtype: float64

# %%
import random

# %%
age = []
height = []
weight = []

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_penalty_shootout_miss_long  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 959                             NaN
# 960                             NaN
# 961                             NaN
# 962                             NaN
# 963                             NaN
#
#                        away_penalty_shootout_miss_long  home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 959                                                NaN            NaN
# 960                                                NaN            NaN
# 961                                                NaN            NaN
# 962                                                NaN            NaN
# 963                                                NaN            NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
# [964 rows x 44 columns]

# %%
df. shape
# Out:
# (964, 44)

# %%
# Loop comprehensions
[age.append(random.randint(18,40)) for _ in range(964)]
print(f"age is now having{len(age)}")
# Out:
# age is now having964

# %%
age
# Out:
# [33,
#  23,
#  35,
#  34,
#  31,
#  40,
#  20,
#  36,
#  22,
#  24,
#  21,
#  37,
#  36,
#  32,
#  33,
#  22,
#  24,
#  19,
#  29,
#  22,
#  27,
#  29,
#  29,
#  40,
#  25,
#  39,
#  33,
#  36,
#  35,
#  31,
#  32,
#  33,
#  35,
#  36,
#  27,
#  28,
#  29,
#  27,
#  31,
#  35,
#  30,
#  32,
#  27,
#  29,
#  29,
#  29,
#  40,
#  32,
#  33,
#  23,
#  19,
#  18,
#  20,
#  33,
#  37,
#  37,
#  22,
#  29,
#  24,
#  29,
#  40,
#  29,
#  32,
#  25,
#  39,
#  21,
#  26,
#  38,
#  38,
#  20,
#  24,
#  20,
#  19,
#  28,
#  27,
#  22,
#  20,
#  20,
#  20,
#  23,
#  33,
#  39,
#  26,
#  23,
#  24,
#  29,
#  24,
#  37,
#  33,
#  20,
#  25,
#  38,
#  21,
#  30,
#  18,
#  27,
#  25,
#  19,
#  20,
#  28,
#  27,
#  34,
#  39,
#  36,
#  30,
#  25,
#  20,
#  27,
#  35,
#  36,
#  36,
#  19,
#  23,
#  40,
#  21,
#  38,
#  21,
#  39,
#  29,
#  31,
#  22,
#  33,
#  38,
#  32,
#  34,
#  29,
#  22,
#  23,
#  28,
#  37,
#  26,
#  38,
#  29,
#  28,
#  31,
#  33,
#  31,
#  33,
#  39,
#  31,
#  40,
#  33,
#  19,
#  36,
#  25,
#  25,
#  24,
#  24,
#  18,
#  19,
#  36,
#  36,
#  24,
#  36,
#  36,
#  20,
#  26,
#  37,
#  26,
#  37,
#  26,
#  35,
#  19,
#  25,
#  29,
#  28,
#  25,
#  35,
#  36,
#  27,
#  20,
#  38,
#  19,
#  26,
#  20,
#  19,
#  40,
#  34,
#  19,
#  20,
#  20,
#  20,
#  31,
#  26,
#  20,
#  29,
#  40,
#  20,
#  32,
#  39,
#  19,
#  20,
#  37,
#  22,
#  27,
#  30,
#  38,
#  35,
#  19,
#  18,
#  21,
#  31,
#  20,
#  22,
#  20,
#  31,
#  34,
#  23,
#  36,
#  23,
#  24,
#  30,
#  25,
#  25,
#  21,
#  19,
#  18,
#  38,
#  26,
#  26,
#  24,
#  35,
#  27,
#  28,
#  27,
#  26,
#  23,
#  39,
#  36,
#  30,
#  29,
#  29,
#  18,
#  24,
#  24,
#  33,
#  38,
#  27,
#  36,
#  32,
#  34,
#  32,
#  35,
#  27,
#  29,
#  22,
#  31,
#  39,
#  37,
#  31,
#  24,
#  19,
#  30,
#  28,
#  21,
#  27,
#  36,
#  37,
#  34,
#  23,
#  21,
#  28,
#  25,
#  37,
#  36,
#  28,
#  23,
#  33,
#  23,
#  22,
#  23,
#  35,
#  22,
#  29,
#  37,
#  22,
#  23,
#  21,
#  34,
#  18,
#  39,
#  36,
#  25,
#  33,
#  27,
#  29,
#  34,
#  30,
#  26,
#  23,
#  19,
#  37,
#  30,
#  29,
#  25,
#  36,
#  34,
#  33,
#  19,
#  24,
#  33,
#  35,
#  24,
#  34,
#  28,
#  35,
#  30,
#  28,
#  33,
#  26,
#  31,
#  40,
#  20,
#  22,
#  21,
#  28,
#  26,
#  20,
#  29,
#  27,
#  28,
#  30,
#  32,
#  31,
#  38,
#  36,
#  39,
#  22,
#  21,
#  21,
#  39,
#  21,
#  32,
#  19,
#  23,
#  38,
#  21,
#  33,
#  22,
#  35,
#  36,
#  39,
#  36,
#  29,
#  27,
#  18,
#  23,
#  37,
#  34,
#  37,
#  22,
#  22,
#  35,
#  31,
#  27,
#  20,
#  35,
#  30,
#  20,
#  26,
#  25,
#  32,
#  27,
#  21,
#  19,
#  29,
#  25,
#  36,
#  34,
#  24,
#  32,
#  19,
#  38,
#  40,
#  18,
#  38,
#  32,
#  20,
#  29,
#  28,
#  35,
#  35,
#  36,
#  25,
#  32,
#  27,
#  35,
#  18,
#  40,
#  38,
#  38,
#  21,
#  29,
#  24,
#  27,
#  32,
#  21,
#  34,
#  19,
#  20,
#  26,
#  22,
#  37,
#  35,
#  20,
#  37,
#  40,
#  23,
#  36,
#  27,
#  31,
#  37,
#  37,
#  24,
#  27,
#  27,
#  23,
#  32,
#  26,
#  40,
#  27,
#  34,
#  18,
#  29,
#  19,
#  30,
#  22,
#  37,
#  39,
#  38,
#  35,
#  36,
#  28,
#  32,
#  35,
#  27,
#  31,
#  31,
#  24,
#  23,
#  37,
#  34,
#  19,
#  24,
#  32,
#  28,
#  35,
#  40,
#  26,
#  25,
#  23,
#  35,
#  18,
#  31,
#  35,
#  29,
#  30,
#  29,
#  28,
#  24,
#  39,
#  38,
#  38,
#  28,
#  20,
#  39,
#  35,
#  21,
#  18,
#  28,
#  30,
#  36,
#  21,
#  25,
#  30,
#  30,
#  30,
#  39,
#  37,
#  37,
#  39,
#  33,
#  19,
#  25,
#  40,
#  20,
#  28,
#  31,
#  33,
#  20,
#  37,
#  24,
#  35,
#  37,
#  22,
#  26,
#  39,
#  28,
#  19,
#  25,
#  30,
#  37,
#  24,
#  19,
#  36,
#  35,
#  32,
#  33,
#  39,
#  30,
#  23,
#  32,
#  26,
#  18,
#  38,
#  28,
#  27,
#  24,
#  25,
#  24,
#  19,
#  35,
#  30,
#  18,
#  24,
#  27,
#  33,
#  28,
#  22,
#  23,
#  18,
#  26,
#  32,
#  34,
#  28,
#  40,
#  24,
#  20,
#  31,
#  22,
#  22,
#  34,
#  39,
#  28,
#  20,
#  20,
#  29,
#  39,
#  24,
#  34,
#  18,
#  35,
#  36,
#  19,
#  27,
#  38,
#  29,
#  24,
#  19,
#  25,
#  33,
#  35,
#  40,
#  37,
#  34,
#  24,
#  26,
#  25,
#  32,
#  29,
#  32,
#  26,
#  20,
#  38,
#  20,
#  33,
#  18,
#  39,
#  30,
#  35,
#  33,
#  20,
#  22,
#  22,
#  38,
#  37,
#  23,
#  21,
#  24,
#  26,
#  30,
#  26,
#  23,
#  28,
#  21,
#  19,
#  34,
#  22,
#  30,
#  31,
#  34,
#  29,
#  33,
#  38,
#  33,
#  21,
#  31,
#  28,
#  18,
#  18,
#  18,
#  20,
#  19,
#  40,
#  26,
#  37,
#  27,
#  33,
#  19,
#  22,
#  23,
#  36,
#  22,
#  23,
#  25,
#  21,
#  26,
#  24,
#  30,
#  18,
#  26,
#  26,
#  33,
#  26,
#  22,
#  33,
#  30,
#  32,
#  21,
#  29,
#  26,
#  30,
#  22,
#  32,
#  37,
#  36,
#  20,
#  30,
#  28,
#  21,
#  38,
#  21,
#  18,
#  30,
#  24,
#  25,
#  34,
#  22,
#  24,
#  26,
#  33,
#  23,
#  38,
#  38,
#  28,
#  34,
#  24,
#  27,
#  19,
#  33,
#  27,
#  36,
#  35,
#  23,
#  34,
#  20,
#  29,
#  31,
#  31,
#  21,
#  29,
#  21,
#  27,
#  36,
#  36,
#  34,
#  33,
#  30,
#  38,
#  19,
#  25,
#  29,
#  19,
#  21,
#  22,
#  18,
#  30,
#  39,
#  24,
#  24,
#  28,
#  31,
#  22,
#  23,
#  20,
#  34,
#  32,
#  29,
#  38,
#  37,
#  35,
#  35,
#  39,
#  36,
#  32,
#  39,
#  23,
#  24,
#  24,
#  35,
#  21,
#  27,
#  26,
#  40,
#  20,
#  36,
#  26,
#  33,
#  36,
#  21,
#  23,
#  37,
#  32,
#  24,
#  36,
#  38,
#  30,
#  40,
#  23,
#  30,
#  18,
#  21,
#  30,
#  33,
#  28,
#  29,
#  31,
#  38,
#  21,
#  29,
#  24,
#  33,
#  29,
#  21,
#  21,
#  25,
#  27,
#  22,
#  19,
#  39,
#  35,
#  34,
#  19,
#  34,
#  25,
#  28,
#  39,
#  36,
#  28,
#  26,
#  24,
#  26,
#  20,
#  29,
#  38,
#  26,
#  31,
#  26,
#  32,
#  21,
#  24,
#  22,
#  20,
#  40,
#  36,
#  33,
#  24,
#  18,
#  24,
#  35,
#  27,
#  29,
#  18,
#  26,
#  30,
#  26,
#  22,
#  27,
#  26,
#  33,
#  40,
#  18,
#  18,
#  39,
#  24,
#  18,
#  40,
#  29,
#  36,
#  31,
#  20,
#  23,
#  19,
#  20,
#  40,
#  30,
#  27,
#  30,
#  31,
#  20,
#  18,
#  26,
#  32,
#  34,
#  19,
#  37,
#  29,
#  40,
#  32,
#  38,
#  34,
#  38,
#  28,
#  25,
#  39,
#  23,
#  39,
#  35,
#  39,
#  36,
#  39,
#  31,
#  31,
#  24,
#  22,
#  23,
#  32,
#  20,
#  28,
#  27,
#  38,
#  36,
#  37,
#  30,
#  28,
#  30,
#  30,
#  37,
#  36,
#  21,
#  21,
#  19,
#  27,
#  18,
#  35,
#  36,
#  26,
#  40,
#  27,
#  32,
#  26,
#  29,
#  30,
#  24,
#  24,
#  28,
#  24,
#  20,
#  23,
#  26,
#  27,
#  20,
#  34,
#  28,
#  28,
#  28,
#  25,
#  20,
#  40,
#  26,
#  35,
#  21,
#  36,
#  23,
#  22,
#  28,
#  40,
#  19,
#  24,
#  36,
#  36,
#  22,
#  18,
#  34,
#  25,
#  35,
#  22,
#  38,
#  36,
#  40,
#  27,
#  32,
#  33,
#  21,
#  22,
#  32,
#  29,
#  39,
#  21,
#  37,
#  23,
#  23,
#  24,
#  23,
#  40,
#  35,
#  40,
#  40,
#  29,
#  38,
#  29,
#  34,
#  28,
#  26,
#  18,
#  34,
#  28,
#  25,
#  32,
#  29,
#  27,
#  40,
#  38,
#  36,
#  34,
#  39,
#  31,
#  20,
#  35,
#  38,
#  35,
#  37,
#  23,
#  21,
#  40,
#  21,
#  30,
#  35,
#  37,
#  31,
#  39,
#  37,
#  39,
#  40]

# %%
# Adding a new column to the Df rame
# Syntax : df['NewColumnName'] = List/sec...

# %%
df['YearsOfExperience']=age

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#                        away_penalty_shootout_miss_long home_red_card  \
# 0    ['3|1:1|Kingsley Coman', '5|2:1|Aurélien Tchou...           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 959                                                NaN           NaN
# 960                                                NaN           NaN
# 961                                                NaN           NaN
# 962                                                NaN           NaN
# 963                                                NaN           NaN
#
#             away_red_card   home_yellow_red_card away_yellow_red_card  \
# 0                     NaN                    NaN                  NaN
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN                  NaN
# 3                     NaN                    NaN                  NaN
# 4                     NaN  Walid Cheddira · 90+3                  NaN
# ..                    ...                    ...                  ...
# 959                   NaN                    NaN                  NaN
# 960                   NaN                    NaN                  NaN
# 961  Plácido Galindo · 70                    NaN                  NaN
# 962                   NaN                    NaN                  NaN
# 963                   NaN                    NaN                  NaN
#
#                                  home_yellow_card_long  \
# 0    ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                                                  NaN
# 2                                                  NaN
# 3    ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4    ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long YearsOfExperience
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...                33
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...                23
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...                35
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...                34
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...                31
# ..                                                 ...               ...
# 959                                                NaN                31
# 960                                                NaN                39
# 961                                                NaN                37
# 962                                                NaN                39
# 963                                                NaN                40
#
# [964 rows x 45 columns]

# %%
df['ASP'] = df['YearsOfExperience'] - df['home_score']

# %%
df.shape
# Out:
# (964, 46)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
#      away_xg  away_penalty      home_manager          home_captain  ...  \
# 0        2.2           2.0    Lionel Scaloni          Lionel Messi  ...
# 1        1.2           NaN      Zlatko Dalić           Luka Modrić  ...
# 2        0.9           NaN  Didier Deschamps           Hugo Lloris  ...
# 3        0.5           NaN    Lionel Scaloni          Lionel Messi  ...
# 4        0.9           NaN   Hoalid Regragui          Romain Saïss  ...
# ..       ...           ...               ...                   ...  ...
# 959      NaN           NaN  Francisco Olazar       Manuel Ferreira  ...
# 960      NaN           NaN   Bosko Simonovic       Milutin Ivković  ...
# 961      NaN           NaN     Octav Luchide          Emerich Vogl  ...
# 962      NaN           NaN        Bob Millar            Tom Florie  ...
# 963      NaN           NaN     Raoul Caudron  Alexandre Villaplane  ...
#
#     home_red_card         away_red_card   home_yellow_red_card  \
# 0             NaN                   NaN                    NaN
# 1             NaN                   NaN                    NaN
# 2             NaN                   NaN                    NaN
# 3             NaN                   NaN                    NaN
# 4             NaN                   NaN  Walid Cheddira · 90+3
# ..            ...                   ...                    ...
# 959           NaN                   NaN                    NaN
# 960           NaN                   NaN                    NaN
# 961           NaN  Plácido Galindo · 70                    NaN
# 962           NaN                   NaN                    NaN
# 963           NaN                   NaN                    NaN
#
#     away_yellow_red_card                              home_yellow_card_long  \
# 0                    NaN  ['45+7&rsquor;|2:0|Enzo Fernández', '90+8&rsqu...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN  ['68&rsquor;|2:0|Cristian Romero', '71&rsquor;...
# 4                    NaN  ['70&rsquor;|1:0|Achraf Dari', '90+1&rsquor;|1...
# ..                   ...                                                ...
# 959                  NaN                                                NaN
# 960                  NaN                                                NaN
# 961                  NaN                                                NaN
# 962                  NaN                                                NaN
# 963                  NaN                                                NaN
#
#                                  away_yellow_card_long  \
# 0    ['55&rsquor;|2:0|Adrien Rabiot', '87&rsquor;|2...
# 1    ['69&rsquor;|2:1|Azzedine Ounahi', '84&rsquor;...
# 2                    ['27&rsquor;|1:0|Sofiane Boufal']
# 3    ['32&rsquor;|0:0|Mateo Kovačić', '32&rsquor;|0...
# 4                           ['87&rsquor;|1:0|Vitinha']
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                home_substitute_in_long  \
# 0    ['64&rsquor;|2:0|Marcos Acuña|for Ángel Di Mar...
# 1    ['61&rsquor;|2:1|Nikola Vlašić|for Andrej Kram...
# 2    ['65&rsquor;|1:0|Marcus Thuram|for Olivier Gir...
# 3    ['62&rsquor;|2:0|Lisandro Martínez|for Leandro...
# 4    ['57&rsquor;|1:0|Achraf Dari|for Romain Saïss'...
# ..                                                 ...
# 959                                                NaN
# 960                                                NaN
# 961                                                NaN
# 962                                                NaN
# 963                                                NaN
#
#                                away_substitute_in_long YearsOfExperience ASP
# 0    ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...                33  30
# 1    ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...                23  21
# 2    ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...                35  33
# 3    ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...                34  31
# 4    ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...                31  30
# ..                                                 ...               ...  ..
# 959                                                NaN                31  30
# 960                                                NaN                39  37
# 961                                                NaN                37  34
# 962                                                NaN                39  36
# 963                                                NaN                40  36
#
# [964 rows x 46 columns]

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df['ASP'].plot(kind = 'bar',color = 'red')
# Out:
# <Axes: >

# %%
df.plot(x='YearsOfExperience',y='home_score',kind = 'bar',color = ['Skyblue','Pink'])
# Out:
# <Axes: xlabel='YearsOfExperience'>

# %%
# Function to get a graph
def getGraph(DataFrame, Column1,Column2):
    from matplotlib import pyplot as plt

# Check the length of column1 and column2
    if len(DataFrame[Column1])==len(DataFrame[Column2]):
       df.plot(x = Column1, y= Column2,kind = 'bar',color = ['Black','Red'])
       print('The graph/plot is succesfully created')

    else:
       print('please check the Column size once')

# %%
getGraph(df, 'home_score','away_score')
# Out:
# The graph/plot is succesfully created
